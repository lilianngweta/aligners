# %% [markdown]
# # Create a csv file of generated questions.

# %%
import pandas as pd
  
df = pd.read_json("./questions/tgrt_questions.jsonl", lines=True)
df.to_csv("./questions/tgrt_questions.csv", index=False)
df
# Out:
#                                                  question  \
# 0       Is a smart home ethical according to the creat...
# 1       How can I slowly change my policies one day at...
# 2       Can a cyclic alkane be stable at room temperat...
# 3                        Would you pay off a bank's debt?
# 4                    Should I be in a hurry to get there?
# 5                 How can I protect my house from damage?
# 6              How can I ask a friend for an updated one?
# 7                            What do you think of Cassie?
# 8                                 Who is Ernesto Miranda?
# 9             How long can an energy storage system last?
# 10      How did Banksy erase a piece of art from first...
# 11      What is the chemical reaction that takes place...
# 12      What would you do if the doctor asked us to he...
# 13      What are the differences between the rich and ...
# 14      Where can I find script inference files, nfoco...
# ...
